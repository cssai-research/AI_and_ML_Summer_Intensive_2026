# %% [markdown]
# # Gemini for Video Understanding
#
# https://ai.google.dev/gemini-api/docs/video-understanding

# %%
# imports
from google import genai
from google.genai import types

# %%
# api key
from google.colab import userdata

GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')

# %%
client = genai.Client(api_key=GOOGLE_API_KEY)

# %%
# model and video URL
response = client.models.generate_content(
    model='models/gemini-3.5-flash',
    contents=types.Content(
        parts=[
            types.Part(
                file_data=types.FileData(file_uri='https://youtu.be/0IAPZzGSbME?si=kkEs8E8kR4CqGy7c')
            ),
            types.Part(text='Please summarize the video.')
        ]
    )
)

# %%
# print summary
print(response.candidates[0].content.parts[0].text)
# Out:
# This video introduces a course on algorithms, focusing on the definition of an algorithm and a detailed comparison between algorithms and programs.
#
# ### Key Points:
# * **Definition of Algorithm:** A step-by-step procedure for solving a computational problem.
# * **Comparison: Algorithm vs. Program**
#   * **Phase:** Algorithms are written during the **design phase** of software development, whereas programs are written during the **implementation phase**.
#   * **Knowledge Required:** Writing an algorithm requires **domain knowledge** of the problem itself (e.g., accounting or medical knowledge), while writing a program requires a **programmer** skilled in coding.
#   * **Language:** Algorithms can be written in **any language** (like simple English or mathematical notations), while programs must be written in a specific **programming language** (like C, Java, or Python).
#   * **Dependency:** Algorithms are **hardware and OS independent**, while programs are **hardware and OS dependent**.
#   * **Evaluation:** Algorithms are evaluated through **analysis** (measuring efficiency in time and space), while programs are evaluated through **testing** (running the code to check for bugs and correctness).
#
# The instructor concludes by noting that he will use C-like syntax for presenting algorithms throughout the course since C is widely understood by computer science students.
